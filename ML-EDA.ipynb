# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r'C:\Users\Anjali Sonawane\Downloads\cars (1).csv')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
df.shape
# Out:
# (205, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
df['horsepower'].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 62      6
# 101     6
# 160     6
# 114     6
# 84      5
# 97      5
# 102     5
# 145     5
# 82      5
# 76      5
# 111     4
# 92      4
# 123     4
# 86      4
# 90      3
# 73      3
# 85      3
# 207     3
# 182     3
# 121     3
# 152     3
# 112     2
# 56      2
# 161     2
# 156     2
# 94      2
# 52      2
# ?       2
# 162     2
# 155     2
# 184     2
# 100     2
# 176     2
# 55      1
# 262     1
# 134     1
# 115     1
# 140     1
# 48      1
# 58      1
# 60      1
# 78      1
# 135     1
# 200     1
# 64      1
# 120     1
# 72      1
# 154     1
# 288     1
# 143     1
# 142     1
# 175     1
# 106     1
# Name: horsepower, dtype: int64

# %%
df['normalized-losses'].replace('?', np.nan,inplace=True)
df['horsepower'].replace('?', np.nan,inplace=True)

# %%
df['normalized-losses'] = df['normalized-losses'].astype('float')
df['horsepower'] = df['horsepower'].astype('float')

# %%
df['normalized-losses'].fillna(df['normalized-losses'].mean(),inplace=True)

# %%
df['horsepower'].fillna(df['horsepower'].mean(),inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type   body-style  \
# 0          3              122.0  alfa-romero       gas  convertible
# 1          3              122.0  alfa-romero       gas  convertible
# 2          1              122.0  alfa-romero       gas    hatchback
# 3          2              164.0         audi       gas        sedan
# 4          2              164.0         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#    horsepower  city-mpg  highway-mpg  price
# 0       111.0        21           27  13495
# ...

# %% [markdown]
# # outliers

# %%
#outliers
df.describe()
# Out:
#         symboling  normalized-losses       width      height  engine-size  \
# count  205.000000         205.000000  205.000000  205.000000   205.000000
# mean     0.834146         122.000000   65.907805   53.724878   126.907317
# std      1.245307          31.681008    2.145204    2.443522    41.642693
# min     -2.000000          65.000000   60.300000   47.800000    61.000000
# 25%      0.000000         101.000000   64.100000   52.000000    97.000000
# 50%      1.000000         122.000000   65.500000   54.100000   120.000000
# 75%      2.000000         137.000000   66.900000   55.500000   141.000000
# max      3.000000         256.000000   72.300000   59.800000   326.000000
#
#        horsepower    city-mpg  highway-mpg         price
# count  205.000000  205.000000   205.000000    205.000000
# mean   104.256158   25.219512    30.751220  13227.478049
# std     39.519211    6.542142     6.886443   7902.651615
# min     48.000000   13.000000    16.000000   5118.000000
# ...

# %%
#detecting outliers
cols = ['symboling','width','height','engine-size','city-mpg','highway-mpg','price']
cols
# Out:
# ['symboling',
#  'width',
#  'height',
#  'engine-size',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
import seaborn as sns 
sns.boxplot(x=df['engine-size'])
# Out:
# <AxesSubplot:xlabel='engine-size'>

# %%
sns.boxplot(x=df['highway-mpg'])
# Out:
# <AxesSubplot:xlabel='highway-mpg'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
Q1,Q3
# Out:
# (symboling         0.0
#  width            64.1
#  height           52.0
#  engine-size      97.0
#  city-mpg         19.0
#  highway-mpg      25.0
#  price          7788.0
#  Name: 0.25, dtype: float64,
#  symboling          2.0
#  width             66.9
#  height            55.5
#  engine-size      141.0
#  city-mpg          30.0
#  highway-mpg       34.0
#  price          16500.0
#  Name: 0.75, dtype: float64)

# %%
IQR = Q3 - Q1
IQR
# Out:
# symboling         2.0
# width             2.8
# height            3.5
# engine-size      44.0
# city-mpg         11.0
# highway-mpg       9.0
# price          8712.0
# dtype: float64

# %%
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR
lower_limit,upper_limit
# Out:
# (symboling        -3.00
#  width            59.90
#  height           46.75
#  engine-size      31.00
#  city-mpg          2.50
#  highway-mpg      11.50
#  price         -5280.00
#  dtype: float64,
#  symboling          5.00
#  width             71.10
#  height            60.75
#  engine-size      207.00
#  city-mpg          46.50
#  highway-mpg       47.50
#  price          29568.00
#  dtype: float64)

# %%
df1 = df[~((df[cols] < lower_limit) |(df[cols] > upper_limit)).any(axis=1)]
df1
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
out_rem = df[~((df[cols] < lower_limit) & (df[cols] > upper_limit)).any(axis=1)]
out_rem
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
#checking whether outliers are removed or not
out_rem[out_rem['width'] < 62]
#out_rem[out_rem['width'] > 74]
# Out:
#     symboling  normalized-losses       make fuel-type body-style drive-wheels  \
# 18          2              121.0  chevrolet       gas  hatchback          fwd
# 43          0              122.0      isuzu       gas      sedan          rwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 18           front   60.3    53.2           l           61        48.0
# 43           front   61.8    53.5         ohc          111        78.0
#
#     city-mpg  highway-mpg  price
# 18        47           53   5151
# 43        24           29   6785

# %% [markdown]
# # Encoding

# %%
num_df = df.select_dtypes(include=['int64','float64']).copy()
num_df
# Out:
#      symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0            3              122.0   64.1    48.8          130       111.0
# 1            3              122.0   64.1    48.8          130       111.0
# 2            1              122.0   65.5    52.4          152       154.0
# 3            2              164.0   66.2    54.3          109       102.0
# 4            2              164.0   66.4    54.3          136       115.0
# ..         ...                ...    ...     ...          ...         ...
# 200         -1               95.0   68.9    55.5          141       114.0
# 201         -1               95.0   68.8    55.5          141       160.0
# 202         -1               95.0   68.9    55.5          173       134.0
# 203         -1               95.0   68.9    55.5          145       106.0
# 204         -1               95.0   68.9    55.5          141       114.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# ...

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df
# Out:
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          4wd           front
# ..           ...       ...          ...          ...             ...
# 200        volvo       gas        sedan          rwd           front
# 201        volvo       gas        sedan          rwd           front
# 202        volvo       gas        sedan          rwd           front
# 203        volvo    diesel        sedan          rwd           front
# 204        volvo       gas        sedan          rwd           front
#
#     engine-type
# 0          dohc
# 1          dohc
# 2          ohcv
# 3           ohc
# 4           ohc
# ..          ...
# ...

# %%
obj_df["OHC_Code"] = np.where(obj_df["engine-type"].str.contains("ohc"), 1, 0)
obj_df.head()
# Out:
#           make fuel-type   body-style drive-wheels engine-location  \
# 0  alfa-romero       gas  convertible          rwd           front
# 1  alfa-romero       gas  convertible          rwd           front
# 2  alfa-romero       gas    hatchback          rwd           front
# 3         audi       gas        sedan          fwd           front
# 4         audi       gas        sedan          4wd           front
#
#   engine-type  OHC_Code
# 0        dohc         1
# 1        dohc         1
# 2        ohcv         1
# 3         ohc         1
# 4         ohc         1

# %%
obj_df[obj_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [make, fuel-type, body-style, drive-wheels, engine-location, engine-type, OHC_Code]
# Index: []

# %%
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
obj_df["make_code"] = ord_enc.fit_transform(obj_df[["make"]])
obj_df[["make", "make_code"]].head(11)
# Out:
#            make  make_code
# 0   alfa-romero        0.0
# 1   alfa-romero        0.0
# 2   alfa-romero        0.0
# 3          audi        1.0
# 4          audi        1.0
# 5          audi        1.0
# 6          audi        1.0
# 7          audi        1.0
# 8          audi        1.0
# 9          audi        1.0
# 10          bmw        2.0

# %%
obj_df["FUEL_Code"] = np.where(obj_df["fuel-type"].str.contains("gas"), 1, 0)
obj_df.head()
# Out:
#           make fuel-type   body-style drive-wheels engine-location  \
# 0  alfa-romero       gas  convertible          rwd           front
# 1  alfa-romero       gas  convertible          rwd           front
# 2  alfa-romero       gas    hatchback          rwd           front
# 3         audi       gas        sedan          fwd           front
# 4         audi       gas        sedan          4wd           front
#
#   engine-type  OHC_Code  make_code  FUEL_Code
# 0        dohc         1        0.0          1
# 1        dohc         1        0.0          1
# 2        ohcv         1        0.0          1
# 3         ohc         1        1.0          1
# 4         ohc         1        1.0          1

# %%
obj_df["engine_loc_Code"] = np.where(obj_df["engine-location"].str.contains("front"), 1, 0)
obj_df.head()
# Out:
#           make fuel-type   body-style drive-wheels engine-location  \
# 0  alfa-romero       gas  convertible          rwd           front
# 1  alfa-romero       gas  convertible          rwd           front
# 2  alfa-romero       gas    hatchback          rwd           front
# 3         audi       gas        sedan          fwd           front
# 4         audi       gas        sedan          4wd           front
#
#   engine-type  OHC_Code  make_code  FUEL_Code  engine_loc_Code
# 0        dohc         1        0.0          1                1
# 1        dohc         1        0.0          1                1
# 2        ohcv         1        0.0          1                1
# 3         ohc         1        1.0          1                1
# 4         ohc         1        1.0          1                1

# %%
obj_df["drive-wheels"].replace('4wd','fwd',inplace=True)
obj_df["drive_wheels_code"] = np.where(obj_df["drive-wheels"].str.contains("rwd"), 1, 0)
obj_df.head()
# Out:
#           make fuel-type   body-style drive-wheels engine-location  \
# 0  alfa-romero       gas  convertible          rwd           front
# 1  alfa-romero       gas  convertible          rwd           front
# 2  alfa-romero       gas    hatchback          rwd           front
# 3         audi       gas        sedan          fwd           front
# 4         audi       gas        sedan          fwd           front
#
#   engine-type  OHC_Code  make_code  FUEL_Code  engine_loc_Code  \
# 0        dohc         1        0.0          1                1
# 1        dohc         1        0.0          1                1
# 2        ohcv         1        0.0          1                1
# 3         ohc         1        1.0          1                1
# 4         ohc         1        1.0          1                1
#
#    drive_wheels_code
# 0                  1
# 1                  1
# 2                  1
# 3                  0
# 4                  0

# %%
obj_df["body-style"] = obj_df["body-style"].astype('category')
print(obj_df.dtypes)
print(obj_df)
# Out:
# make                   object
# fuel-type              object
# body-style           category
# drive-wheels           object
# engine-location        object
# engine-type            object
# OHC_Code                int32
# make_code             float64
# FUEL_Code               int32
# engine_loc_Code         int32
# drive_wheels_code       int32
# dtype: object
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          fwd           front
# ..           ...       ...          ...          ...             ...
# 200        volvo       gas        sedan          rwd           front
# ...

# %%
obj_df["body_style_cat"] = obj_df["body-style"].cat.codes
obj_df.head()
# Out:
#           make fuel-type   body-style drive-wheels engine-location  \
# 0  alfa-romero       gas  convertible          rwd           front
# 1  alfa-romero       gas  convertible          rwd           front
# 2  alfa-romero       gas    hatchback          rwd           front
# 3         audi       gas        sedan          fwd           front
# 4         audi       gas        sedan          fwd           front
#
#   engine-type  OHC_Code  make_code  FUEL_Code  engine_loc_Code  \
# 0        dohc         1        0.0          1                1
# 1        dohc         1        0.0          1                1
# 2        ohcv         1        0.0          1                1
# 3         ohc         1        1.0          1                1
# 4         ohc         1        1.0          1                1
#
#    drive_wheels_code  body_style_cat
# 0                  1               0
# 1                  1               0
# 2                  1               2
# ...

# %%
num_df.head()
# Out:
#    symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0          3              122.0   64.1    48.8          130       111.0
# 1          3              122.0   64.1    48.8          130       111.0
# 2          1              122.0   65.5    52.4          152       154.0
# 3          2              164.0   66.2    54.3          109       102.0
# 4          2              164.0   66.4    54.3          136       115.0
#
#    city-mpg  highway-mpg  price
# 0        21           27  13495
# 1        21           27  16500
# 2        19           26  16500
# 3        24           30  13950
# 4        18           22  17450

# %% [markdown]
# # Skewness

# %%
from scipy.stats import skew

# %%
for col in num_df:
    print(col)
    print(skew(num_df[col]))
    
    plt.figure()
    sns.distplot(num_df[col])
    plt.show()
# Out:
# symboling
# 0.20952469094997359
# normalized-losses
# 0.8485348696008058
# width
# 0.8973753485201392
# height
# 0.06265991683394276
# engine-size
# 1.9333748457840114
# horsepower
# 1.3875147343096037
# city-mpg
# 0.6588377533622138
# highway-mpg
# 0.5360379305163596
# price
# 1.791937476907277

# %%
sns.heatmap(num_df.corr(),annot=True)
plt.show()

# %%
num_df['normalized-losses'] = np.sqrt(num_df['normalized-losses'])

# %%
skew(num_df['normalized-losses'])
# Out:
# 0.423806868842261

# %%
car_new = pd.concat([num_df,obj_df],axis = 1)
car_new.head()
# Out:
#    symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0          3          11.045361   64.1    48.8          130       111.0
# 1          3          11.045361   64.1    48.8          130       111.0
# 2          1          11.045361   65.5    52.4          152       154.0
# 3          2          12.806248   66.2    54.3          109       102.0
# 4          2          12.806248   66.4    54.3          136       115.0
#
#    city-mpg  highway-mpg  price         make  ...   body-style drive-wheels  \
# 0        21           27  13495  alfa-romero  ...  convertible          rwd
# 1        21           27  16500  alfa-romero  ...  convertible          rwd
# 2        19           26  16500  alfa-romero  ...    hatchback          rwd
# 3        24           30  13950         audi  ...        sedan          fwd
# 4        18           22  17450         audi  ...        sedan          fwd
#
# ...

# %%
car_new.drop(car_new.iloc[:, 9:15], inplace = True, axis = 1)

# %%
car_new
# Out:
#      symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0            3          11.045361   64.1    48.8          130       111.0
# 1            3          11.045361   64.1    48.8          130       111.0
# 2            1          11.045361   65.5    52.4          152       154.0
# 3            2          12.806248   66.2    54.3          109       102.0
# 4            2          12.806248   66.4    54.3          136       115.0
# ..         ...                ...    ...     ...          ...         ...
# 200         -1           9.746794   68.9    55.5          141       114.0
# 201         -1           9.746794   68.8    55.5          141       160.0
# 202         -1           9.746794   68.9    55.5          173       134.0
# 203         -1           9.746794   68.9    55.5          145       106.0
# 204         -1           9.746794   68.9    55.5          141       114.0
#
#      city-mpg  highway-mpg  price  OHC_Code  make_code  FUEL_Code  \
# ...

# %% [markdown]
# # Data Normalization

# %%
from sklearn.preprocessing import StandardScaler

# %%
for col in car_new:
    scaler = StandardScaler()
    car_new[col]=scaler.fit_transform(car_new[[col]])

# %%
car_new.head()
# Out:
#    symboling  normalized-losses     width    height  engine-size  horsepower  \
# 0   1.743470           0.063555 -0.844782 -2.020417     0.074449    0.171065
# 1   1.743470           0.063555 -0.844782 -2.020417     0.074449    0.171065
# 2   0.133509           0.063555 -0.190566 -0.543527     0.604046    1.261807
# 3   0.938490           1.322843  0.136542  0.235942    -0.431076   -0.057230
# 4   0.938490           1.322843  0.230001  0.235942     0.218885    0.272529
#
#    city-mpg  highway-mpg     price  OHC_Code  make_code  FUEL_Code  \
# 0 -0.646553    -0.546059  0.033935  0.290957  -1.948256   0.328798
# 1 -0.646553    -0.546059  0.415118  0.290957  -1.948256   0.328798
# 2 -0.953012    -0.691627  0.415118  0.290957  -1.948256   0.328798
# 3 -0.186865    -0.109354  0.091652  0.290957  -1.788499   0.328798
# 4 -1.106241    -1.273900  0.535625  0.290957  -1.788499   0.328798
#
#    engine_loc_Code  drive_wheels_code  body_style_cat
# ...
